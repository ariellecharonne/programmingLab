# %% [markdown]
# ### **1.Consumo di alcol per paese**
# Esegui un’**analisi esplorativa** focalizzata sul **consumo di alcol**.
# Analizza i seguenti aspetti:
# * Visualizza i primi 10 paesi ordinati per total_litres_of_pure_alcohol (dal più alto)
#
# * Calcola la media del consumo di birra, vino, e distillati
#
# * Crea una nuova colonna alcohol_index che sia: `(beer_servings + wine_servings + spirit_servings) / 3`
#
# * Trova il paese con il valore massimo di alcohol_index
#
# * Filtra solo i paesi che consumano più di 100 birre all’anno
#
# Crea un bar chart dei 10 paesi con più consumo totale (total_litres_of_pure_alcohol)
#
# Crea un line plot con wine_servings ordinato per paese (usa sort_values)

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv")
df

top10 = df.sort_values(by='total_litres_of_pure_alcohol', ascending=False)
print(top10.head(10))
print(df[['beer_servings', 'wine_serving','spirit_serving']].mean())
df['alcohol_index'] = df['beer_servings'] + df['wine_servings'] + df['spirit_servings']/3
print(df.loc[df['alcohol_index'].idxmax()])
print(df[df['beer_servings'] > 100])
top10 = df.sort_values('total_litres_of_pure_alcohol' , ascending=False).head(10)  # bar chart
top10.plot(x='country',y='total_litres_of_pure_alcohol', kind='bar')
df.sort_values(by='wine_servings').plot(y='wine_serving',kind='line')
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 15              Belarus            142              373             42
# 98            Lithuania            343              244             56
# 3               Andorra            245              138            312
# 68              Grenada            199              438             28
# 61               France            127              151            370
# 45       Czech Republic            361              170            134
# 141  Russian Federation            247              326             73
# 99           Luxembourg            236              133            271
# 155            Slovakia            196              293            116
# 81              Ireland            313              118            165
#
#      total_litres_of_pure_alcohol
# 15                           14.4
# 98                           12.9
# 3                            12.4
# 68                           11.9
# 61                           11.8
# 45                           11.8
# 141                          11.5
# 99                           11.4
# 155                          11.4
# 81                           11.4
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 8
#       4 df
#       5
#       6 top10 = df.sort_values(by='total_litres_of_pure_alcohol', ascending=False)
#       7 print(top10.head(10))
# ----> 8 print(df[['beer_servings', 'wine_serving', 'spirit_serving']].mean())
#       9 df['alcohol_index'] = df['beer_servings'] + df['wine_servings'] + df['spirit_servings']/3
#      10 print(df.loc[df['alcohol_index'].idxmax()])
#      11 print(df[df['beer_servings'] > 100])
#
# File c:\Users\GLOBAL STORE\miniconda3\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4380                 indexer = [indexer]
#    4381         else:
#    4382             if is_iterator(key):
#    4383                 key = list(key)
# -> 4384             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4385
#    4386         # take() does not accept boolean indexers
#    4387         if getattr(indexer, "dtype", None) == bool:
#
# File c:\Users\GLOBAL STORE\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File c:\Users\GLOBAL STORE\miniconda3\Lib\site-packages\pandas\core\indexes\base.py:6355, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6352     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6355 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['wine_serving', 'spirit_serving'] not in index"

# %%
# %pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.2-cp313-cp313-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\global store\miniconda3\lib\site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\global store\miniconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting tzdata (from pandas)
#   Downloading tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\global store\miniconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.2-cp313-cp313-win_amd64.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 2.1 MB/s eta 0:00:05
#    --- ------------------------------------ 0.8/9.7 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.0/9.7 MB 1.4 MB/s eta 0:00:07
#    ------ --------------------------------- 1.6/9.7 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.7 MB 1.5 MB/s eta 0:00:06
#    -------- ------------------------------- 2.1/9.7 MB 1.5 MB/s eta 0:00:06
#    --------- ------------------------------ 2.4/9.7 MB 1.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.6/9.7 MB 1.5 MB/s eta 0:00:05
#    ------------ --------------------------- 3.1/9.7 MB 1.4 MB/s eta 0:00:05
#    ------------- -------------------------- 3.4/9.7 MB 1.4 MB/s eta 0:00:05
#    ------------- -------------------------- 3.4/9.7 MB 1.4 MB/s eta 0:00:05
#    --------------- ------------------------ 3.7/9.7 MB 1.4 MB/s eta 0:00:05
#    ----------------- ---------------------- 4.2/9.7 MB 1.4 MB/s eta 0:00:05
#    ------------------ --------------------- 4.5/9.7 MB 1.4 MB/s eta 0:00:04
#    -------------------- ------------------- 5.0/9.7 MB 1.4 MB/s eta 0:00:04
#    --------------------- ------------------ 5.2/9.7 MB 1.4 MB/s eta 0:00:04
#    ---------------------- ----------------- 5.5/9.7 MB 1.4 MB/s eta 0:00:03
#    ----------------------- ---------------- 5.8/9.7 MB 1.4 MB/s eta 0:00:03
#    ------------------------ --------------- 6.0/9.7 MB 1.4 MB/s eta 0:00:03
#    ------------------------- -------------- 6.3/9.7 MB 1.4 MB/s eta 0:00:03
#    -------------------------- ------------- 6.6/9.7 MB 1.4 MB/s eta 0:00:03
#    --------------------------- ------------ 6.8/9.7 MB 1.4 MB/s eta 0:00:03
#    ------------------------------ --------- 7.3/9.7 MB 1.4 MB/s eta 0:00:02
#    ------------------------------- -------- 7.6/9.7 MB 1.4 MB/s eta 0:00:02
#    --------------------------------- ------ 8.1/9.7 MB 1.4 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.4/9.7 MB 1.5 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.7 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.7 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.7 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 1.5 MB/s  0:00:06
# Downloading tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# Installing collected packages: tzdata, pandas
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    -------------------- ------------------- 1/2 [pandas]
#    ---------------------------------------- 2/2 [pandas]
#
# Successfully installed pandas-3.0.2 tzdata-2026.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### **2.Analisi offerte di lavoro**
#
# Esegui un’**analisi esplorativa** focalizzata sui **lavori nel campo dei dati in ciascun paese**.
# Analizza i seguenti aspetti per ogni paese:
#
# * Lo **stipendio medio annuale** (`salary_year_avg`)
# * Il **numero totale di offerte di lavoro** (job count)
# * L’intervallo degli stipendi: **valore minimo e massimo** (`min` / `max`)
#
# Rappresenta graficamente lo stipendio medio (`salary_year_avg`) per `job_title_short` usando un grafico a barre orizzontali. Ordina i dati dallo stipendio più alto al più basso. Includi un titolo e le etichette per gli assi x e y.

# %%
import pandas as pd
df =pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/alcohol-consumption/drinks.csv")
print(df.columns)
print(df['beer_servings'].mean())
print(df['country'].count())
print(df['beer_servings'].min())
print(df['beer_servings'].max())
df.plot(x='country', y='beer_servings',kind='bar')
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol'],
#       dtype='str')
# 106.16062176165804
# 193
# 0
# 376
# <Axes: xlabel='country'>

# %%
import pandas as pd
from datasets import load_dataset

dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %% [markdown]
# ### **3. Analisi vendite (dataset tips)**
#
# Esegui un’**analisi esplorativa** focalizzata sulle **vendite giornaliere**.
# Analizza i seguenti aspetti per ogni giorno (`day`):
#
# * Il **conto medio** (`total_bill`)
# * Il **numero totale di osservazioni** (conteggio delle righe)
# * Il **valore minimo e massimo** del conto (`total_bill` → `min` / `max`)
#
# * Crea una nuova colonna `conto_per_persona` che sia:
#   `total_bill / size`
#
# * Trova il giorno con il **conto medio più alto**
#
# Rappresenta graficamente il **conto medio (`total_bill`) per giorno** usando un **grafico a barre**.
# Ordina i dati dal valore più alto al più basso.
# Aggiungi titolo ed etichette agli assi.

# %%
url = "https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"
df = pd.read_csv(url)

df.head()
df['total_bill'].mean()
df['total_bill'].count()
df['total_bill'].min()
df['total_bill'].max()
df['conto_per_persona'] = df['total_bill'] / df['size']
df.groupby('day')['total_bill'].mean().idxmax()   # giorno con il conto piu alto
df.groupby('day')['total_bill'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='day'>
