# %%
# creer 5 nbrs aleatoire entre 10 et 50 et transforme en array , garde seulement ceux sup a 30
inport numply as np
import random 

num = [random.randint(0,100) for i in range(10)]
#   transformer en array 
num_array = np.array(num)
#   garder les valeur entre 10 et 50
filtered = [(num_array >= 10) & (num_array <= 50)]
#  garder uniquement ceux sup a 30
np.where(num_array > 30)



import numpy as np
arr = np.array([5,8,2,9,1])
print(np.argmax(arr)) #3
print(n0p.argmin(arr)) #4
2. arr = np.array([10,None,20])
arr * 2 corrigeons ce code 
arr = np.array([10,np.nan,20])
printaa(0arr * 2)
3. arr = np.array([100,200,np.nan,400]) trouvons la moyenne sans erreur
average_arr = np.nanmean_array(arr) 
print(average_arr)
